# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
"""Constants"""

mu0 = 4 * np.pi * 1e-7

I = 100

a = 0.35

d = a

z = np.linspace(-0.4, 0.4, 400)

# %%
"""Magnetic field from the upper coil"""

B1 = (mu0 * I * a**2) / (2 * (a**2 + (z - d/2)**2)**1.5)

# %%
"""Magnetic field from the lower coil"""

B2 = (mu0 * I * a**2) / (2 * (a**2 + (z + d/2)**2)**1.5)

# %%
"""Total magnetic field"""

Bz = B1 + B2

# %%
"""Plot the magnetic field"""

plt.figure(figsize=(6,4))

plt.plot(z, Bz, color='blue', linewidth=1.5)

plt.xlim(-0.4, 0.4)
plt.ylim(0.5e-4, 3.0e-4)

plt.xlabel("Z-axis (m)")
plt.ylabel("Bz (T)")
plt.title("Z-component Magnetic Field")

plt.grid(False)

plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

plt.show()

# %%
"""Magnetic field from the second coil"""

B2 = (mu0 * I * a**2) / (2 * (a**2 + (z - z2)**2)**1.5)

# %%
"""Total magnetic field"""

Bz = B1 + B2

# %%
"""Plot the magnetic field"""

plt.figure(figsize=(7,5))

plt.plot(z, Bz, color='blue', linewidth=2)

plt.xlabel("Z-axis (m)")
plt.ylabel("Bz (T)")

plt.title("Helmholtz Coil Magnetic Field")

plt.xlim(-0.4,0.4)

plt.grid(True)

plt.show()

# %%
"""Print the maximum magnetic field"""

print("Maximum Bz =", np.max(Bz), "Tesla")
# Out:
# Maximum Bz = 0.00025690751010060597 Tesla
